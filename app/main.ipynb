# %%
from fastapi import FastAPI
from app.schema import CustomerData
from app.model_loader import predict_churn

app = FastAPI(title="Churn Prediction API")

@app.get("/")
def home():
    return {"status":"API is running"}

@app.post("/predict")
def predict(data: CustomerData):
    result = predict_churn(data.dict())
    return {"churn_prediction": result}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from fastapi import FastAPI
# ----> 2 from app.schema import CustomerData
#       3 from app.model_loader import predict_churn
#       5 app = FastAPI(title="Churn Prediction API")
#
# ModuleNotFoundError: No module named 'app'
